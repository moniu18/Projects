# %% [markdown]
# <a href="https://colab.research.google.com/github/moniu18/Projects/blob/main/Copy_of_facerecognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image=cv2.imread('hema.jpg')

# %%
cv2_imshow(image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-8d211f7bb68b> in <module>()
# ----> 1 cv2_imshow(image)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      20       image.
#      21   """
# ---> 22   a = a.clip(0, 255).astype('uint8')
#      23   # cv2 stores colors as BGR; convert to RGB
#      24   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
# !pip install face_recognition
# Out:
# ...
#      |████████████████████████████████| 100.2MB 41kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566173 sha256=e8aba7e179ba7226543137af7902f1bd39835d62ef6e398fd9e27e87a9de9f10
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...

# %%
import face_recognition as fr

# %%
locs=fr.face_locations(image)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-340680a58954> in <module>()
# ----> 1 locs=fr.face_locations(image)
#
# /usr/local/lib/python3.6/dist-packages/face_recognition/api.py in face_locations(img, number_of_times_to_upsample, model)
#     119         return [_trim_css_to_bounds(_rect_to_css(face.rect), img.shape) for face in _raw_face_locations(img, number_of_times_to_upsample, "cnn")]
#     120     else:
# --> 121         return [_trim_css_to_bounds(_rect_to_css(face), img.shape) for face in _raw_face_locations(img, number_of_times_to_upsample, model)]
#     122
#     123
#
# /usr/local/lib/python3.6/dist-packages/face_recognition/api.py in _raw_face_locations(img, number_of_times_to_upsample, model)
#     103         return cnn_face_detector(img, number_of_times_to_upsample)
#     104     else:
# ...

# %%
print(len(locs),"face(s) detected")
# Out:
# 1 face(s) detected

# %%
locs
# Out:
# [(333, 760, 718, 375)]

# %%
for face in locs:
 cv2.rectangle(image,(face[3],face[0]),(face[1],face[2]),(0,255,0),2)

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=960x1280 at 0x7F7A3404CB00>

# %%
0.1**0.1
# Out:
# 0.7943282347242815

# %%
0.05**0.05
# Out:
# 0.8608916593317348
